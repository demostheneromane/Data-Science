# %% [markdown]
# 2.19 Uma variável categórica apresenta tres categorias , com as seguintes frequencias de ocrrencia :
#
#
# |Categoria| Frequencia|
# |--|--
# |A|13|
# |B|28|
# |C|9|
#
#    * Calcule a percentagem dos valores em relação a cada uma das categorias
#
#
#  |Categoria| Frequencia|percentagem(%)|
#  |--|--|--|
#  |A|13|26%|
#  |B|28|58%|
#  |C|9|18%|
#  |total|50|100%|
#
#
#    * Que conclusões vc consegue tirar em relação a essas categorias ?
#
#
#       rep : A categoria B representa mais que a metade das categorias ou seja 58% das categorias seguir das categorias A com 26% e C com 18%. Nessa amostragem a categoria C tem uma frequencia mais que  tres vezes (3x) menor que a  categoria B. A categoria B mais a categoria A representa 84% de amostra
#
#
#
# 2.20 Os dados a seguir representam as respostas para duas perguntas formuladas em uma pesquisa realizada com 40 estudantes de faculdade que se especializavam em administração de negócios - qual o seu genero ? (masculino = M; feminino = F) e qual é a sua área de especialização ? (análise contábil = A, computação e sistemas de Informação = C , marketing = M )
#
#  * Posicione os dados em uma tabela de contingencia na qual as duas linhas representam as categorias relacionadas a genero e as tres colunas representam as principais categorias relacionadas a especialização academica .
#
#                                                   Area de especialização
#
#
#
#  |Genero|Análise contábil(A)|Computação e sistemas de Informação(C)|Marking (M)|
#  |--|--|--|--|
#  |Masculino(M)|--|--|--|
#  |Feminino(F)|--|--|--|
#
#
#  * Construa tabelas de contingencia baseadas em percentagens de todas as 40 respostas dos estudantes , baseadas nas percentagens de linha e baseadas nas percentagens de colunas .
#
#
#
#  || | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | | |||
#  |--| --| --| --|-- | --| --|-- | --| --| --| --|-- |-- | --| --| --| --| --| --| --| --| --|-- | --| --|-- | --|-- | --|-- | | --| --| --|-- | --|-- |-- |--|--|
#  |Genero :| M|M |M | F| M|F | F| M| F| M| F| M|M |M |M |F | F| M|F | F|M |M |M |M |F | M|F |F | M| M|F | M| M|M | M|F |M |F |M|M
#  | Especialização :| A| C|C | M| A|C | A|A | C|C |A |A |A |M |C | M| A|A | A|C | C| C| A| A| M| M| C|A |A |A | C|C | A| A| A|A |C|C|A|C|
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    Tabela de contingencia baseadas nas percentagens de linha
#
#
#                                               Area de especialização
#    |Genero|Análise contábil(A)|Computação e sistemas de Informação(C)|Marketing (M)|Total|
#    |--|--|--|--|--|
#    |Masculino(M)|56%|36%|8%|100%|
#    |Feminino(F)|40%|40%|20%|100%|
#
#
#
#
#
#
#
#
#
#
#    Tabela de contingencia baseadas na percentagens de colunas.
#
#                                                                               Genero
#    |Area de especialização| Masculino(M)|Feminino(F)|
#    |--|--|--|
#    |Análise contábil(A)| 56%|40%|
#    |Computação e sistemas de Informação|36%|40%|
#    |Marketing(M)|8%|20%|
#    |Total|100%|100%|
#
#
#
#
#
#
#
#
#
#
# 2.21 A Transportation Security Administration (Administração de Segurança nos Transportes) relatou que de 1 de janeiro 2008 a 18 fevereiro de 2009 mais de 14000 itens cujo transporte é proibido foram coletados no Aeroporto Internacional de Palm Beach . As categorias eram as seguintes :
#
#
# |Categorias| Frequencia|
# |--|--|
# |Inflamáveis/substancias tóxicas|8350|
# |Facas e Laminas|4134|
# |Ferramentas proibidas|753|
# |Objetos cortantes|497|
# |Outros|357|
#
#
#  * Calcule a percentagem de valores em cada uma das categorias .
#
#
#
#  |Categorias| Frequencia|percentagem(%)|
#  |--|--|--|
#  |Inflamáveis/substancias tóxicas|8350|59.26%|
#  |Facas e Laminas|4134|29.34%|
#  |Ferramentas proibidas|753|5.34%|
#  |Objetos cortantes|497|3.53%|
#  |Outros|357|2.53%|
#  |Total|14091|100%|
#
#
#  * Que conclusões vc consegue tirar em relação aos itens cujo transporte é proibido ?
#
#     rep : Os objetos inflamáveis/substancias tóxicas representam mais que a metade ou seja 59.26%  ,seguir de Facas e laminas com 29.34% do transporte proibido que significa que a maior parte do transporte proibido se concentrar entre as categorias dos objetos inflamáveis/substancias tóxicas e facas e laminas que representam 88.6% do transporte proibido . Os objetos Ferramentas proibidas , objetos cortantes e os outros representam 11.4% do transporte proibido .
